# %%
#!pip install pandas
#!pip install scanpy
import pandas as pd
import scanpy as sc
import anndata
import numpy as np

# %%
adat = sc.read_10x_mtx(
    'data/filtered_gene_bc_matrices/hg19/',  # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=True)

# %%
pd.DataFrame(data=adata.X, index=adata.obs_names, columns=adata.var_names)

# %%
adat.var_names
# Out:
# Index(['MIR1302-10', 'FAM138A', 'OR4F5', 'RP11-34P13.7', 'RP11-34P13.8',
#        'AL627309.1', 'RP11-34P13.14', 'RP11-34P13.9', 'AP006222.2',
#        'RP4-669L17.10',
#        ...
#        'KIR3DL2-1', 'AL590523.1', 'CT476828.1', 'PNRC2-1', 'SRSF10-1',
#        'AC145205.1', 'BAGE5', 'CU459201.1', 'AC002321.2', 'AC002321.1'],
#       dtype='object', length=32738)

# %%
adat.obs_names
# Out:
# Index(['AAACATACAACCAC-1', 'AAACATTGAGCTAC-1', 'AAACATTGATCAGC-1',
#        'AAACCGTGCTTCCG-1', 'AAACCGTGTATGCG-1', 'AAACGCACTGGTAC-1',
#        'AAACGCTGACCAGT-1', 'AAACGCTGGTTCTT-1', 'AAACGCTGTAGCCA-1',
#        'AAACGCTGTTTCTG-1',
#        ...
#        'TTTCAGTGTCACGA-1', 'TTTCAGTGTCTATC-1', 'TTTCAGTGTGCAGT-1',
#        'TTTCCAGAGGTGAG-1', 'TTTCGAACACCTGA-1', 'TTTCGAACTCTCAT-1',
#        'TTTCTACTGAGGCA-1', 'TTTCTACTTCCTCG-1', 'TTTGCATGAGAGGC-1',
#        'TTTGCATGCCTCAC-1'],
#       dtype='object', length=2700)

# %%
adat2 = adat.transpose()

# %%
adat.obs_names
# Out:
# Index(['AAACATACAACCAC-1', 'AAACATTGAGCTAC-1', 'AAACATTGATCAGC-1',
#        'AAACCGTGCTTCCG-1', 'AAACCGTGTATGCG-1', 'AAACGCACTGGTAC-1',
#        'AAACGCTGACCAGT-1', 'AAACGCTGGTTCTT-1', 'AAACGCTGTAGCCA-1',
#        'AAACGCTGTTTCTG-1',
#        ...
#        'TTTCAGTGTCACGA-1', 'TTTCAGTGTCTATC-1', 'TTTCAGTGTGCAGT-1',
#        'TTTCCAGAGGTGAG-1', 'TTTCGAACACCTGA-1', 'TTTCGAACTCTCAT-1',
#        'TTTCTACTGAGGCA-1', 'TTTCTACTTCCTCG-1', 'TTTGCATGAGAGGC-1',
#        'TTTGCATGCCTCAC-1'],
#       dtype='object', length=2700)

# %%
adata3.obs_names
# Out:
# Index(['G1_0', 'G1_1', 'G1_2', 'G1_3', 'G1_4', 'G1_5', 'G1_6', 'G1_7', 'G1_8',
#        'G1_9', 'G1_10', 'G1_11', 'G1_12', 'G1_13', 'G1_14', 'G1_15', 'G1_16',
#        'G1_17', 'G1_18', 'G1_19', 'G2_0', 'G2_1', 'G2_2', 'G2_3', 'G2_4',
#        'G2_5', 'G2_6', 'G2_7', 'G2_8', 'G2_9', 'G2_10', 'G2_11', 'G2_12',
#        'G2_13', 'G2_14', 'G2_15', 'G2_16', 'G2_17', 'G2_18', 'G2_19', 'G3_0',
#        'G3_1', 'G3_2', 'G3_3', 'G3_4', 'G3_5', 'G3_6', 'G3_7', 'G3_8', 'G3_9',
#        'G3_10', 'G3_11', 'G3_12', 'G3_13', 'G3_14', 'G3_15', 'G3_16', 'G3_17',
#        'G3_18', 'G3_19'],
#       dtype='object', name='Gene')

# %%
adata3.obs_names
# Out:
# Index([], dtype='object')

# %%
test_data = pd.read_table("/home/meric/Downloads/test-data.tsv",index_col=0)

# %%
test_data.head()
# Out:
#            C1_0       C1_1       C1_2       C1_3       C1_4       C1_5  \
# Gene
# G1_0  10.727042   8.315798   6.063312   5.687848   9.374830  10.380233
# G1_1  11.184697   8.328764   8.928004   5.978260   8.296328   8.712758
# G1_2  10.673568   9.595251   7.286249  10.833456  12.708644   8.502129
# G1_3   5.998427  11.936252  12.113981   9.858911   8.206825   7.702442
# G1_4   8.688702  10.510972  11.841540  13.105279  10.795819  10.026125
#
#            C1_6       C1_7       C1_8       C1_9  ...      B_40      B_41  \
# Gene                                              ...
# G1_0  13.210917   7.549024   4.743596  11.042742  ...  2.148934  5.765072
# G1_1  10.512857  10.069351  10.376496   8.968665  ...  5.467242  3.366546
# G1_2   6.869061  11.439294   8.439351   8.224518  ...  4.161527  5.390796
# G1_3   8.545305  10.458131  10.239256   9.517474  ...  7.215840  5.928617
# G1_4  10.301745   9.012321   9.378242   9.046324  ...  1.720287  3.883959
#
# ...

# %%
test_data.transpose()
# Out:
# Gene       G1_0       G1_1       G1_2       G1_3       G1_4       G1_5  \
# C1_0  10.727042  11.184697  10.673568   5.998427   8.688702   6.448220
# C1_1   8.315798   8.328764   9.595251  11.936252  10.510972   9.212565
# C1_2   6.063312   8.928004   7.286249  12.113981  11.841540  10.509237
# C1_3   5.687848   5.978260  10.833456   9.858911  13.105279  12.195323
# C1_4   9.374830   8.296328  12.708644   8.206825  10.795819   7.096022
# ...         ...        ...        ...        ...        ...        ...
# B_45   0.713568   0.000000   0.116301   3.834849   2.702222   5.379625
# B_46   2.613277   3.968883   3.025528   0.429191   3.626690   1.523949
# B_47   0.000000   1.003473   3.686433   1.307429   3.049609   4.390295
# B_48   2.263453   6.644671   2.348062   2.991722   6.063447   4.079892
# B_49   5.331783   2.771534   0.812386   0.255414   1.044988   2.850720
#
# Gene       G1_6       G1_7       G1_8       G1_9  ...     G3_10     G3_11  \
# ...

# %%
andata = sc.AnnData(test_data)
# Out:
# /tmp/ipykernel_22696/3882858182.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   andata = sc.AnnData(test_data)

# %%
andata.obs_names
# Out:
# Index(['G1_0', 'G1_1', 'G1_2', 'G1_3', 'G1_4', 'G1_5', 'G1_6', 'G1_7', 'G1_8',
#        'G1_9', 'G1_10', 'G1_11', 'G1_12', 'G1_13', 'G1_14', 'G1_15', 'G1_16',
#        'G1_17', 'G1_18', 'G1_19', 'G2_0', 'G2_1', 'G2_2', 'G2_3', 'G2_4',
#        'G2_5', 'G2_6', 'G2_7', 'G2_8', 'G2_9', 'G2_10', 'G2_11', 'G2_12',
#        'G2_13', 'G2_14', 'G2_15', 'G2_16', 'G2_17', 'G2_18', 'G2_19', 'G3_0',
#        'G3_1', 'G3_2', 'G3_3', 'G3_4', 'G3_5', 'G3_6', 'G3_7', 'G3_8', 'G3_9',
#        'G3_10', 'G3_11', 'G3_12', 'G3_13', 'G3_14', 'G3_15', 'G3_16', 'G3_17',
#        'G3_18', 'G3_19'],
#       dtype='object', name='Gene')

# %%
df = pd.read_table(input_path,index_col=0)

# %%
df_t = df.transpose()
df_t.head()
# Out:
# Gene       G1_0       G1_1       G1_2       G1_3       G1_4       G1_5  \
# C1_0  10.727042  11.184697  10.673568   5.998427   8.688702   6.448220
# C1_1   8.315798   8.328764   9.595251  11.936252  10.510972   9.212565
# C1_2   6.063312   8.928004   7.286249  12.113981  11.841540  10.509237
# C1_3   5.687848   5.978260  10.833456   9.858911  13.105279  12.195323
# C1_4   9.374830   8.296328  12.708644   8.206825  10.795819   7.096022
#
# Gene       G1_6       G1_7       G1_8       G1_9  ...     G3_10     G3_11  \
# C1_0  11.443035  12.141987   8.282951  10.168248  ...  4.212497  1.686463
# C1_1  12.577425   8.792781   6.067199   8.445051  ...  2.694165  0.230444
# C1_2  11.165940   7.129255  10.557955  10.995422  ...  3.018777  4.529927
# C1_3  10.156436  15.516433   7.842166  10.428821  ...  4.356187  2.623310
# C1_4   7.890382  11.093775   8.064053  12.644984  ...  1.970077  4.921857
#
# Gene     G3_12     G3_13     G3_14     G3_15     G3_16     G3_17     G3_18  \
# ...

# %%
df_t.columns
# Out:
# Index(['G1_0', 'G1_1', 'G1_2', 'G1_3', 'G1_4', 'G1_5', 'G1_6', 'G1_7', 'G1_8',
#        'G1_9', 'G1_10', 'G1_11', 'G1_12', 'G1_13', 'G1_14', 'G1_15', 'G1_16',
#        'G1_17', 'G1_18', 'G1_19', 'G2_0', 'G2_1', 'G2_2', 'G2_3', 'G2_4',
#        'G2_5', 'G2_6', 'G2_7', 'G2_8', 'G2_9', 'G2_10', 'G2_11', 'G2_12',
#        'G2_13', 'G2_14', 'G2_15', 'G2_16', 'G2_17', 'G2_18', 'G2_19', 'G3_0',
#        'G3_1', 'G3_2', 'G3_3', 'G3_4', 'G3_5', 'G3_6', 'G3_7', 'G3_8', 'G3_9',
#        'G3_10', 'G3_11', 'G3_12', 'G3_13', 'G3_14', 'G3_15', 'G3_16', 'G3_17',
#        'G3_18', 'G3_19'],
#       dtype='object', name='Gene')

# %%
obj = sc.AnnData(df_t,df_t.index.to_frame(),df_t.columns.to_frame())
# Out:
# /tmp/ipykernel_22696/3131765415.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   obj = sc.AnnData(df_t,df_t.index.to_frame(),df_t.columns.to_frame())

# %%
obj.obs_names
# Out:
# Index(['C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7', 'C1_8',
#        'C1_9',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=350)

# %%
obj.var_names
# Out:
# Index(['G1_0', 'G1_1', 'G1_2', 'G1_3', 'G1_4', 'G1_5', 'G1_6', 'G1_7', 'G1_8',
#        'G1_9', 'G1_10', 'G1_11', 'G1_12', 'G1_13', 'G1_14', 'G1_15', 'G1_16',
#        'G1_17', 'G1_18', 'G1_19', 'G2_0', 'G2_1', 'G2_2', 'G2_3', 'G2_4',
#        'G2_5', 'G2_6', 'G2_7', 'G2_8', 'G2_9', 'G2_10', 'G2_11', 'G2_12',
#        'G2_13', 'G2_14', 'G2_15', 'G2_16', 'G2_17', 'G2_18', 'G2_19', 'G3_0',
#        'G3_1', 'G3_2', 'G3_3', 'G3_4', 'G3_5', 'G3_6', 'G3_7', 'G3_8', 'G3_9',
#        'G3_10', 'G3_11', 'G3_12', 'G3_13', 'G3_14', 'G3_15', 'G3_16', 'G3_17',
#        'G3_18', 'G3_19'],
#       dtype='object', name='Gene')

# %%
sc.pp.filter_cells(obj, min_genes=10)

# %%
obj.obs_names
# Out:
# Index(['C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7', 'C1_8',
#        'C1_9',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=344)

# %%
sc.pp.filter_genes(obj, min_cells=3)

# %%
obj.obs_names
# Out:
# Index(['C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7', 'C1_8',
#        'C1_9',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=350)

# %%
obj
# Out:
# AnnData object with n_obs × n_vars = 344 × 60
#     obs: 0, 'n_genes'
#     var: 'Gene', 'n_cells'

# %%
sc.pp.calculate_qc_metrics(obj,percent_top=None, log1p=False, inplace=True)
obj = obj[obj.obs.n_genes_by_counts < 2000, :]
#adata = adata[adata.obs.pct_counts_mt < max_pct_mt_count, :]
#sc.pp.normalize_total(obj, target_sum=1e4)
#sc.pp.log1p(obj)
#sc.pp.highly_variable_genes(obj,min_mean=0.0125,max_mean=3,min_disp=0.5)
#obj = obj[:,obj.var.highly_variable]
#sc.pp.regress_out(adata,['total_counts'])
#sc.pp.scale(obj,max_value=10)
#sc.tl.pca(obj,svd_solver='arpack')

# %%
sc.pp.normalize_total(obj, target_sum=1e4)
# Out:
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pp.log1p(obj)

# %%
sc.pp.highly_variable_genes(obj,min_mean=0.0125,max_mean=3,min_disp=0.5)

# %%
sc.pp.scale(obj,max_value=10)
sc.tl.pca(obj,svd_solver='arpack')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [410], line 2
#       1 sc.pp.scale(obj,max_value=10)
# ----> 2 sc.tl.pca(obj,svd_solver='arpack')
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_pca.py:188, in pca(data, n_comps, zero_center, svd_solver, random_state, return_info, use_highly_variable, dtype, copy, chunked, chunk_size)
#     184         X = X.toarray()
#     185     pca_ = PCA(
#     186         n_components=n_comps, svd_solver=svd_solver, random_state=random_state
#     187     )
# --> 188     X_pca = pca_.fit_transform(X)
#     189 elif issparse(X) and zero_center:
#     190     from sklearn.decomposition import PCA
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:433, in PCA.fit_transform(self, X, y)
# ...

# %%
obj.X
# Out:
# array([[ 8.9423716e-01,  8.9744943e-01,  9.4835430e-01, ...,
#          5.3346988e-02,  3.0570412e-01,  2.5184509e-01],
#        [ 7.4132627e-01,  7.3424703e-01,  8.8363677e-01, ...,
#          5.7232815e-01, -5.0801430e-03, -4.3541193e-01],
#        [ 5.5264527e-01,  7.7463281e-01,  7.1616727e-01, ...,
#         -9.6967602e-03, -1.8668216e+00,  5.2573848e-01],
#        ...,
#        [-2.7139823e+00, -4.6256822e-01,  2.6220185e-01, ...,
#          3.2710737e-01,  3.6943978e-01,  3.6976674e-01],
#        [-8.6022094e-02,  5.6731778e-01, -2.5542403e-02, ...,
#          3.1300241e-01,  6.2272131e-02,  3.8472760e-01],
#        [ 4.6213928e-01,  1.1401736e-01, -6.3294923e-01, ...,
#          4.2852548e-01, -1.1127333e-03, -1.8660018e-01]], dtype=float32)

# %%
def sc_filter (input_path,min_genes=200,min_cell=10,genes_by_counts=2000):
    with open(input_path) as test_data:
        adata = anndata.read_csv(test_data, delimiter='\t')
        sc.pp.filter_cells(adata, min_genes=min_genes)
        sc.pp.filter_genes(adata, min_cells=min_cell)
        #adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
        sc.pp.calculate_qc_metrics(adata,percent_top=None, log1p=False, inplace=True)
        adata = adata[adata.obs.n_genes_by_counts < genes_by_counts, :]
        #adata = adata[adata.obs.pct_counts_mt < max_pct_mt_count, :]
        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)
        #sc.pp.highly_variable_genes(adata,min_mean=0.0125,max_mean=3,min_disp=0.5)
        #adata = adata[:,adata.var.highly_variable]
        #sc.pp.regress_out(adata,['total_counts'])
        sc.pp.scale(adata,max_value=10)
        sc.tl.pca(adata,svd_solver='arpack')
        #out_path=input_path
    return(adata)
# Out:
# Index(['G1_0', 'G1_1', 'G1_2', 'G1_3', 'G1_4', 'G1_5', 'G1_6', 'G1_7', 'G1_8',
#        'G1_9', 'G1_10', 'G1_11', 'G1_12', 'G1_13', 'G1_14', 'G1_15', 'G1_16',
#        'G1_17', 'G1_18', 'G1_19', 'G2_0', 'G2_1', 'G2_2', 'G2_3', 'G2_4',
#        'G2_5', 'G2_6', 'G2_7', 'G2_8', 'G2_9', 'G2_10', 'G2_11', 'G2_12',
#        'G2_13', 'G2_14', 'G2_15', 'G2_16', 'G2_17', 'G2_18', 'G2_19', 'G3_0',
#        'G3_1', 'G3_2', 'G3_3', 'G3_4', 'G3_5', 'G3_6', 'G3_7', 'G3_8', 'G3_9',
#        'G3_10', 'G3_11', 'G3_12', 'G3_13', 'G3_14', 'G3_15', 'G3_16', 'G3_17',
#        'G3_18', 'G3_19'],
#       dtype='object', name='Gene')

# %%
df = pd.read_table(input_path)

# %%
df.head()
# Out:
#    Gene       C1_0       C1_1       C1_2       C1_3       C1_4       C1_5  \
# 0  G1_0  10.727042   8.315798   6.063312   5.687848   9.374830  10.380233
# 1  G1_1  11.184697   8.328764   8.928004   5.978260   8.296328   8.712758
# 2  G1_2  10.673568   9.595251   7.286249  10.833456  12.708644   8.502129
# 3  G1_3   5.998427  11.936252  12.113981   9.858911   8.206825   7.702442
# 4  G1_4   8.688702  10.510972  11.841540  13.105279  10.795819  10.026125
#
#         C1_6       C1_7       C1_8  ...      B_40      B_41      B_42  \
# 0  13.210917   7.549024   4.743596  ...  2.148934  5.765072  3.293237
# 1  10.512857  10.069351  10.376496  ...  5.467242  3.366546  2.007725
# 2   6.869061  11.439294   8.439351  ...  4.161527  5.390796  0.941041
# 3   8.545305  10.458131  10.239256  ...  7.215840  5.928617  2.665901
# 4  10.301745   9.012321   9.378242  ...  1.720287  3.883959  0.000000
#
#        B_43      B_44      B_45      B_46      B_47      B_48      B_49
# ...

# %%
df.columns
#df.index
# Out:
# Index(['Gene', 'C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7',
#        'C1_8',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=351)

# %%
df.head()
# Out:
#            C1_0       C1_1       C1_2       C1_3       C1_4       C1_5  \
# Gene
# G1_0  10.727042   8.315798   6.063312   5.687848   9.374830  10.380233
# G1_1  11.184697   8.328764   8.928004   5.978260   8.296328   8.712758
# G1_2  10.673568   9.595251   7.286249  10.833456  12.708644   8.502129
# G1_3   5.998427  11.936252  12.113981   9.858911   8.206825   7.702442
# G1_4   8.688702  10.510972  11.841540  13.105279  10.795819  10.026125
#
#            C1_6       C1_7       C1_8       C1_9  ...      B_40      B_41  \
# Gene                                              ...
# G1_0  13.210917   7.549024   4.743596  11.042742  ...  2.148934  5.765072
# G1_1  10.512857  10.069351  10.376496   8.968665  ...  5.467242  3.366546
# G1_2   6.869061  11.439294   8.439351   8.224518  ...  4.161527  5.390796
# G1_3   8.545305  10.458131  10.239256   9.517474  ...  7.215840  5.928617
# G1_4  10.301745   9.012321   9.378242   9.046324  ...  1.720287  3.883959
#
# ...

# %%
df.iloc[:,0]
# Out:
# 0      G1_0
# 1      G1_1
# 2      G1_2
# 3      G1_3
# 4      G1_4
# 5      G1_5
# 6      G1_6
# 7      G1_7
# 8      G1_8
# 9      G1_9
# 10    G1_10
# 11    G1_11
# 12    G1_12
# 13    G1_13
# 14    G1_14
# 15    G1_15
# 16    G1_16
# 17    G1_17
# 18    G1_18
# 19    G1_19
# 20     G2_0
# 21     G2_1
# 22     G2_2
# 23     G2_3
# 24     G2_4
# 25     G2_5
# 26     G2_6
# 27     G2_7
# 28     G2_8
# 29     G2_9
# 30    G2_10
# 31    G2_11
# 32    G2_12
# 33    G2_13
# 34    G2_14
# 35    G2_15
# 36    G2_16
# 37    G2_17
# 38    G2_18
# 39    G2_19
# 40     G3_0
# 41     G3_1
# 42     G3_2
# 43     G3_3
# 44     G3_4
# 45     G3_5
# 46     G3_6
# 47     G3_7
# 48     G3_8
# 49     G3_9
# 50    G3_10
# 51    G3_11
# 52    G3_12
# 53    G3_13
# 54    G3_14
# 55    G3_15
# 56    G3_16
# 57    G3_17
# 58    G3_18
# 59    G3_19
# Name: Gene, dtype: object

# %%
df.columns[1:]
# Out:
# Index(['C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7', 'C1_8',
#        'C1_9',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=350)

# %%
df.head()
# Out:
#    Gene       C1_0       C1_1       C1_2       C1_3       C1_4       C1_5  \
# 0  G1_0  10.727042   8.315798   6.063312   5.687848   9.374830  10.380233
# 1  G1_1  11.184697   8.328764   8.928004   5.978260   8.296328   8.712758
# 2  G1_2  10.673568   9.595251   7.286249  10.833456  12.708644   8.502129
# 3  G1_3   5.998427  11.936252  12.113981   9.858911   8.206825   7.702442
# 4  G1_4   8.688702  10.510972  11.841540  13.105279  10.795819  10.026125
#
#         C1_6       C1_7       C1_8  ...      B_40      B_41      B_42  \
# 0  13.210917   7.549024   4.743596  ...  2.148934  5.765072  3.293237
# 1  10.512857  10.069351  10.376496  ...  5.467242  3.366546  2.007725
# 2   6.869061  11.439294   8.439351  ...  4.161527  5.390796  0.941041
# 3   8.545305  10.458131  10.239256  ...  7.215840  5.928617  2.665901
# 4  10.301745   9.012321   9.378242  ...  1.720287  3.883959  0.000000
#
#        B_43      B_44      B_45      B_46      B_47      B_48      B_49
# ...

# %%
df.values[:,1:]
# Out:
# array([[10.727041766822063, 8.315798402273703, 6.063312171784347, ...,
#         0.0, 2.263452855096117, 5.331783153755307],
#        [11.184697371865182, 8.328763564756319, 8.92800366413029, ...,
#         1.0034734676745152, 6.644671451636395, 2.771533731228907],
#        [10.673568241968724, 9.595250837439572, 7.286249023244903, ...,
#         3.6864328567746254, 2.3480622796579427, 0.8123860000008538],
#        ...,
#        [2.017229462128215, 5.183239965473585, 1.7890919243626076, ...,
#         3.506695688334827, 3.4857173770264973, 4.066229891675114],
#        [3.468311257244676, 2.0503367576994336, 0.064903408160645, ...,
#         4.072764941590227, 2.4754037031772085, 2.1025580502851104],
#        [2.932067393146384, 0.8265778663808439, 4.804156354574026, ...,
#         3.834111999179223, 4.018205853482701, 1.3356402180068745]],
#       dtype=object)

# %%
#adata = anndata.AnnData(X: df.iloc[1:,1:],
                        #obs: df.iloc[:,0:1],
                        #var: df.iloc[0:1,:])
df.iloc[:,0:1]
# Out:
#      Gene
# 0    G1_0
# 1    G1_1
# 2    G1_2
# 3    G1_3
# 4    G1_4
# 5    G1_5
# 6    G1_6
# 7    G1_7
# 8    G1_8
# 9    G1_9
# 10  G1_10
# 11  G1_11
# 12  G1_12
# 13  G1_13
# 14  G1_14
# 15  G1_15
# 16  G1_16
# 17  G1_17
# 18  G1_18
# 19  G1_19
# 20   G2_0
# 21   G2_1
# 22   G2_2
# 23   G2_3
# 24   G2_4
# 25   G2_5
# 26   G2_6
# 27   G2_7
# 28   G2_8
# 29   G2_9
# 30  G2_10
# 31  G2_11
# 32  G2_12
# 33  G2_13
# 34  G2_14
# 35  G2_15
# 36  G2_16
# 37  G2_17
# 38  G2_18
# 39  G2_19
# 40   G3_0
# 41   G3_1
# 42   G3_2
# 43   G3_3
# 44   G3_4
# 45   G3_5
# 46   G3_6
# 47   G3_7
# 48   G3_8
# 49   G3_9
# 50  G3_10
# 51  G3_11
# 52  G3_12
# 53  G3_13
# 54  G3_14
# 55  G3_15
# 56  G3_16
# 57  G3_17
# 58  G3_18
# 59  G3_19

# %%
df.iloc[0:1,1:]
# Out:
#         C1_0      C1_1      C1_2      C1_3     C1_4       C1_5       C1_6  \
# 0  10.727042  8.315798  6.063312  5.687848  9.37483  10.380233  13.210917
#
#        C1_7      C1_8       C1_9  ...      B_40      B_41      B_42      B_43  \
# 0  7.549024  4.743596  11.042742  ...  2.148934  5.765072  3.293237  3.969615
#
#        B_44      B_45      B_46  B_47      B_48      B_49
# 0  0.751296  0.713568  2.613277   0.0  2.263453  5.331783
#
# [1 rows x 350 columns]

# %%
df.iloc[1:,1:]
# Out:
#          C1_0       C1_1       C1_2       C1_3       C1_4       C1_5  \
# 1   11.184697   8.328764   8.928004   5.978260   8.296328   8.712758
# 2   10.673568   9.595251   7.286249  10.833456  12.708644   8.502129
# 3    5.998427  11.936252  12.113981   9.858911   8.206825   7.702442
# 4    8.688702  10.510972  11.841540  13.105279  10.795819  10.026125
# 5    6.448220   9.212565  10.509237  12.195323   7.096022  13.557241
# 6   11.443035  12.577425  11.165940  10.156436   7.890382   9.833142
# 7   12.141987   8.792781   7.129255  15.516433  11.093775   7.587247
# 8    8.282951   6.067199  10.557955   7.842166   8.064053  11.508129
# 9   10.168248   8.445051  10.995422  10.428821  12.644984   8.451139
# 10   9.804701   9.668946  10.724503  10.841588  12.797230   7.416485
# 11  10.605170   6.389204  11.845755  14.416164  12.035693   8.157277
# 12   9.389933   9.810866  12.151674   9.940919  10.959324  10.459348
# 13   7.979071   8.302642   8.731512  12.075560   7.578871   8.512749
# ...

# %%
df.iloc[0:,1:]
# Out:
#          C1_0       C1_1       C1_2       C1_3       C1_4       C1_5  \
# 0   10.727042   8.315798   6.063312   5.687848   9.374830  10.380233
# 1   11.184697   8.328764   8.928004   5.978260   8.296328   8.712758
# 2   10.673568   9.595251   7.286249  10.833456  12.708644   8.502129
# 3    5.998427  11.936252  12.113981   9.858911   8.206825   7.702442
# 4    8.688702  10.510972  11.841540  13.105279  10.795819  10.026125
# 5    6.448220   9.212565  10.509237  12.195323   7.096022  13.557241
# 6   11.443035  12.577425  11.165940  10.156436   7.890382   9.833142
# 7   12.141987   8.792781   7.129255  15.516433  11.093775   7.587247
# 8    8.282951   6.067199  10.557955   7.842166   8.064053  11.508129
# 9   10.168248   8.445051  10.995422  10.428821  12.644984   8.451139
# 10   9.804701   9.668946  10.724503  10.841588  12.797230   7.416485
# 11  10.605170   6.389204  11.845755  14.416164  12.035693   8.157277
# 12   9.389933   9.810866  12.151674   9.940919  10.959324  10.459348
# ...

# %%
df.T.iloc[1:,0:].shape
# Out:
# (350, 60)

# %%
df.iloc[0:1,1:].shape
# Out:
# (1, 350)

# %%
df.iloc[:,0:1].shape
# Out:
# (60, 1)

# %%
aa = anndata.AnnData(X=df.iloc[0:,1:],
                        obs=df.iloc[0:1,1:], #cells,
                        var=df.iloc[:,0:1])
# Out:
# /tmp/ipykernel_22696/3934733387.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   aa = anndata.AnnData(X=df.iloc[0:,1:],
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [363], line 1
# ----> 1 aa = anndata.AnnData(X=df.iloc[0:,1:],
#       2                         obs=df.iloc[0:1,1:], #cells,
#       3                         var=df.iloc[:,0:1])
#
# ...

# %%
def sc_filter (input_path,min_genes=200,min_cell=10,genes_by_counts=2000):
        df = pd.read_table(input_path,index_col=0)
        #test_data.t = test_data.transpose()
        #adata = sc.AnnData(test_data)
        df_t = df.transpose()
        adata = sc.AnnData(df_t,
                           df_t.index.to_frame(),
                           df_t.columns.to_frame())
        #adata = sc.AnnData(test_data)
        #sc.pp.filter_cells(adata, min_genes=min_genes)
        #sc.pp.filter_genes(adata, min_cells=min_cell)
        #adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
        #sc.pp.calculate_qc_metrics(adata,percent_top=None, log1p=False, inplace=True)
        #adata = adata[adata.obs.n_genes_by_counts < genes_by_counts, :]
        #adata = adata[adata.obs.pct_counts_mt < max_pct_mt_count, :]
        #sc.pp.normalize_total(adata, target_sum=1e4)
        #sc.pp.log1p(adata)
        #sc.pp.highly_variable_genes(adata,min_mean=0.0125,max_mean=3,min_disp=0.5)
        #adata = adata[:,adata.var.highly_variable]
        #sc.pp.regress_out(adata,['total_counts'])
        #sc.pp.scale(adata,max_value=10)
        #sc.tl.pca(adata,svd_solver='arpack')
        #out_path=input_path
        return(adata)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [221], line 1
# ----> 1 df.obs_names
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'obs_names'

# %%
adata3 = sc_filter(input_path,min_genes=200,min_cell=10,genes_by_counts=2000)
# Out:
# /tmp/ipykernel_22696/3835277263.py:6: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = sc.AnnData(df,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [269], line 1
# ----> 1 adata3 = sc_filter(input_path,min_genes=200,min_cell=10,genes_by_counts=2000)
#
# Cell In [268], line 6, in sc_filter(input_path, min_genes, min_cell, genes_by_counts)
#       3 #test_data.t = test_data.transpose()
#       4 #adata = sc.AnnData(test_data)
#       5 df_t = df.transpose()
# ----> 6 adata = sc.AnnData(df,
#       7                    df_t.index.to_frame(),
#       8                    df_t.columns.to_frame())
#       9 #adata = sc.AnnData(test_data)
# ...

# %%
adata3.var_names #should be gene names
# Out:
# Index(['C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7', 'C1_8',
#        'C1_9',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=350)

# %%
sc.pl.pca(adata3,color="G3_19")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [206], line 1
# ----> 1 sc.pl.pca(adata3,color="G3_19")
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:871, in pca(adata, annotate_var_explained, show, return_fig, save, **kwargs)
#     823 """\
#     824 Scatter plot in PCA coordinates.
#     825
#    (...)
#     868 pp.pca
#     869 """
#     870 if not annotate_var_explained:
# --> 871     return embedding(
#     872         adata, 'pca', show=show, return_fig=return_fig, save=save, **kwargs
#     873     )
#     874 else:
#     876     if 'pca' not in adata.obsm.keys() and 'X_pca' not in adata.obsm.keys():
#
# ...

# %%
with open("/home/meric/Downloads/test-data.tsv") as test_data:
    testd = anndata.read_csv(test_data, delimiter='\t')

# %%
testd
# Out:
# AnnData object with n_obs × n_vars = 60 × 350

# %%
#testd.X
sc.pp.filter_cells(testd, min_genes=10)

# %%
testd.var['mt'] = testd.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'

# %%
testd.X[0:10]
# Out:
# array([[10.727042 ,  8.315799 ,  6.063312 , ...,  0.       ,  2.2634528,
#          5.3317833],
#        [11.184697 ,  8.328764 ,  8.928003 , ...,  1.0034735,  6.6446714,
#          2.7715337],
#        [10.673568 ,  9.595251 ,  7.286249 , ...,  3.6864328,  2.3480623,
#          0.812386 ],
#        ...,
#        [12.141987 ,  8.792781 ,  7.1292553, ...,  3.0060804,  2.9943373,
#          4.403419 ],
#        [ 8.28295  ,  6.0671988, 10.557956 , ...,  1.3439142,  0.       ,
#          1.3760922],
#        [10.168248 ,  8.445051 , 10.995421 , ...,  4.2715955,  2.274549 ,
#          2.1981733]], dtype=float32)

# %%
sc.pp.filter_genes(testd, min_cells=3)

# %%
testd.X[0:10]
# Out:
# array([[10.727042 ,  8.315799 ,  6.063312 , ...,  0.       ,  2.2634528,
#          5.3317833],
#        [11.184697 ,  8.328764 ,  8.928003 , ...,  1.0034735,  6.6446714,
#          2.7715337],
#        [10.673568 ,  9.595251 ,  7.286249 , ...,  3.6864328,  2.3480623,
#          0.812386 ],
#        ...,
#        [12.141987 ,  8.792781 ,  7.1292553, ...,  3.0060804,  2.9943373,
#          4.403419 ],
#        [ 8.28295  ,  6.0671988, 10.557956 , ...,  1.3439142,  0.       ,
#          1.3760922],
#        [10.168248 ,  8.445051 , 10.995421 , ...,  4.2715955,  2.274549 ,
#          2.1981733]], dtype=float32)

# %%
sc.pp.calculate_qc_metrics(testd,percent_top=None, log1p=False, inplace=True)

# %%
testd.obs.head()
# Out:
#       n_genes
# G1_0      323
# G1_1      311
# G1_2      327
# G1_3      322
# G1_4      318

# %%
sc.pl.violin(testd, ['n_genes_by_counts', 'total_counts'],
             jitter=0.4, multi_panel=True)

# %%
testd2 = testd[testd.obs.n_genes_by_counts <3000, :]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [157], line 1
# ----> 1 testd2 = testd[testd.obs.n_genes_by_counts <3000, :]
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'n_genes_by_counts'

# %%
sc.pl.violin(testd2, ['n_genes_by_counts', 'total_counts'],
             jitter=0.4, multi_panel=True)

# %%
testd.var_names
# Out:
# Index(['C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7', 'C1_8',
#        'C1_9',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=350)

# %%
testd2.var_names
# Out:
# Index(['C1_0', 'C1_1', 'C1_2', 'C1_3', 'C1_4', 'C1_5', 'C1_6', 'C1_7', 'C1_8',
#        'C1_9',
#        ...
#        'B_40', 'B_41', 'B_42', 'B_43', 'B_44', 'B_45', 'B_46', 'B_47', 'B_48',
#        'B_49'],
#       dtype='object', length=350)

# %%
len(testd2.X)
# Out:
# 60

# %%
sc.pp.normalize_total(testd2, target_sum=1e4)
# Out:
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
testd2
# Out:
# AnnData object with n_obs × n_vars = 60 × 350
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts'
#     var: 'mt', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
sc.pp.log1p(testd2)

# %%
testd2.var
# Out:
#          mt  n_cells  n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# C1_0  False       54                 54     4.636722              10.000000
# C1_1  False       56                 56     4.630222               6.666667
# C1_2  False       53                 53     4.615625              11.666667
# C1_3  False       53                 53     5.002755              11.666667
# C1_4  False       50                 50     4.578776              16.666667
# ...     ...      ...                ...          ...                    ...
# B_45  False       56                 56     4.863889               6.666667
# B_46  False       56                 56     4.884638               6.666667
# B_47  False       57                 57     4.891303               5.000000
# B_48  False       56                 56     4.988493               6.666667
# B_49  False       55                 55     4.716388               8.333333
#
#       total_counts
# C1_0    278.203308
# ...

# %%
sc.pp.highly_variable_genes(testd2)
#testd2.var_names
# Out:
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_highly_variable_genes.py:200: RuntimeWarning: overflow encountered in expm1
#   X = np.expm1(X)
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_utils.py:11: RuntimeWarning: overflow encountered in multiply
#   mean_sq = np.multiply(X, X).mean(axis=axis, dtype=np.float64)
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_utils.py:12: RuntimeWarning: invalid value encountered in subtract
#   var = mean_sq - mean**2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [126], line 1
# ----> 1 sc.pp.highly_variable_genes(testd2)
#       2 #testd2.var_names
#
# ...

# %%
len(testd2[:,testd2.var.highly_variable].X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [86], line 1
# ----> 1 len(testd2[:,testd2.var.highly_variable].X)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'highly_variable'

# %%
testd2 = testd2[:,testd2.var.highly_variable]

# %%
testd2
# Out:
# View of AnnData object with n_obs × n_vars = 60 × 0
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts'
#     var: 'mt', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
sc.pp.scale(testd2,max_value=10)
#sc.tl.pca(adata,svd_solver='arpack')
# Out:
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
testd2
# Out:
# AnnData object with n_obs × n_vars = 60 × 0
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts'
#     var: 'mt', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg'

# %%
testd2.obs
# Out:
#        n_genes  n_genes_by_counts  total_counts
# G1_0       323                323   1753.672119
# G1_1       311                311   1719.074341
# G1_2       327                327   1676.496582
# G1_3       322                322   1811.392578
# G1_4       318                318   1753.665771
# G1_5       310                310   1728.698730
# G1_6       307                307   1738.726807
# G1_7       307                307   1721.174072
# G1_8       321                321   1743.875977
# G1_9       317                317   1739.433350
# G1_10      317                317   1744.158447
# G1_11      317                317   1682.198975
# G1_12      321                321   1732.086548
# G1_13      325                325   1708.608643
# G1_14      321                321   1686.414917
# G1_15      322                322   1779.501099
# G1_16      313                313   1731.535645
# G1_17      309                309   1738.510132
# G1_18      316                316   1761.633301
# ...

# %%
sc.tl.pca(testd2,svd_solver='arpack')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [108], line 1
# ----> 1 sc.tl.pca(testd2,svd_solver='arpack')
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_pca.py:188, in pca(data, n_comps, zero_center, svd_solver, random_state, return_info, use_highly_variable, dtype, copy, chunked, chunk_size)
#     184         X = X.toarray()
#     185     pca_ = PCA(
#     186         n_components=n_comps, svd_solver=svd_solver, random_state=random_state
#     187     )
# --> 188     X_pca = pca_.fit_transform(X)
#     189 elif issparse(X) and zero_center:
#     190     from sklearn.decomposition import PCA
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:433, in PCA.fit_transform(self, X, y)
#     411 def fit_transform(self, X, y=None):
# ...

# %%
#sc.pp.regress_out(testd2,['total_counts'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 sc.pp.regress_out(testd2,['total_counts'])
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:600, in regress_out(adata, keys, n_jobs, copy)
#     576 """\
#     577 Regress out (mostly) unwanted sources of variation.
#     578
#    (...)
#     597 Depending on `copy` returns or updates `adata` with the corrected data matrix.
#     598 """
#     599 start = logg.info(f'regressing out {keys}')
# --> 600 if issparse(adata.X):
#     601     logg.info('    sparse input is densified and may ' 'lead to high memory use')
#     602 adata = adata.copy() if copy else adata
#
# AttributeError: 'ArrayView' object has no attribute 'X'

# %%
#!mkdir data
#!wget http://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz -O data/pbmc3k_filtered_gene_bc_matrices.tar.gz
#!cd data; tar -xzf pbmc3k_filtered_gene_bc_matrices.tar.gz
#!mkdir write

# %%
adata = sc.read_10x_mtx(
    'data/filtered_gene_bc_matrices/hg19/',  # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=True)

# %%
input_path = "/home/meric/Downloads/test-data.tsv"

# %%
# it will get path of the input
# it will write output file path

# %%
# https://stackoverflow.com/questions/65117950/how-do-i-create-anndata-object-from-a-pandas-data-frame-count-matrix
#def sc_filter (input_path,out_path,min_genes=200,min_cell=10,genes_by_counts=2000,max_pct_mt_count=5):
def sc_filter (input_path,min_genes=200,min_cell=10,genes_by_counts=2000):
    with open(input_path) as test_data:
        adata = anndata.read_csv(test_data, delimiter='\t')
        sc.pp.filter_cells(adata, min_genes=min_genes)
        sc.pp.filter_genes(adata, min_cells=min_cell)
        #adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
        sc.pp.calculate_qc_metrics(adata,percent_top=None, log1p=False, inplace=True)
        adata = adata[adata.obs.n_genes_by_counts < genes_by_counts, :]
        #adata = adata[adata.obs.pct_counts_mt < max_pct_mt_count, :]
        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)
        #sc.pp.highly_variable_genes(adata,min_mean=0.0125,max_mean=3,min_disp=0.5)
        #adata = adata[:,adata.var.highly_variable]
        #sc.pp.regress_out(adata,['total_counts'])
        sc.pp.scale(adata,max_value=10)
        sc.tl.pca(adata,svd_solver='arpack')
        #out_path=input_path
    return(adata)

# %%
adata_filtered = sc_filter(input_path,min_genes=10,min_cell=3,genes_by_counts=10000)
#sc_filter(input_path)
# Out:
# /home/meric/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pl.pca(adata, color='G1_0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [151], line 1
# ----> 1 sc.pl.pca(adata, color='G1_0')
#
# File ~/Desktop/single-cell-pathway-analysis/venv/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:871, in pca(adata, annotate_var_explained, show, return_fig, save, **kwargs)
#     823 """\
#     824 Scatter plot in PCA coordinates.
#     825
#    (...)
#     868 pp.pca
#     869 """
#     870 if not annotate_var_explained:
# --> 871     return embedding(
#     872         adata, 'pca', show=show, return_fig=return_fig, save=save, **kwargs
#     873     )
#     874 else:
#     876     if 'pca' not in adata.obsm.keys() and 'X_pca' not in adata.obsm.keys():
#
# ...

# %%
adata_filtered.obs
# Out:
#        n_genes  n_genes_by_counts  total_counts
# G1_0       323                323   1753.672119
# G1_1       311                311   1719.074341
# G1_2       327                327   1676.496582
# G1_3       322                322   1811.392578
# G1_4       318                318   1753.665771
# G1_5       310                310   1728.698730
# G1_6       307                307   1738.726807
# G1_7       307                307   1721.174072
# G1_8       321                321   1743.875977
# G1_9       317                317   1739.433350
# G1_10      317                317   1744.158447
# G1_11      317                317   1682.198975
# G1_12      321                321   1732.086548
# G1_13      325                325   1708.608643
# G1_14      321                321   1686.414917
# G1_15      322                322   1779.501099
# G1_16      313                313   1731.535645
# G1_17      309                309   1738.510132
# G1_18      316                316   1761.633301
# ...
